# %% [markdown]
# Web Scrapping - Job Descriptions (Data Scientist)
# URL Source: LINKEDIN Public
#
# PLP Project
# ResGen Team

# %%
pip install requests beautifulsoup4 pandas
pip install re
pip install html

# %%
import requests  # Make sure to import requests, to fetch the job listings from the LinkedIn page
from bs4 import BeautifulSoup # to parse the HTML and extract the job details
import pandas as pd
import json
import re # For data cleaning 
import html
import time

# %%
# Define the URL
# Here is a LINKEDIN Public JD with 975 Records (Above 975 records is getting webpage error, suspect restriction implemented from LinkedIn)
# Define the base URL
base_url = "https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/search?keywords=Data%2BScientist&location=Singapore&geoId=102454443&trk=public_jobs_jobs-search-bar_search-submit&currentJobId=3744333339&position=6&pageNum=0&start="

# %%
# Import the display function
from IPython.display import display

# %%
# Initialize empty lists to store job data
job_titles = []
company_names = []
preferred_qualifications = []
job_links = []

# Set the range for the 'start' parameter
start_range = range(50, 975, 50)  # Adjust the end value as needed. Max 975 for LinkedIn

# Loop through the range of 'start' values
for start_value in start_range:
    # Construct the URL with the current 'start' value
    url = base_url + str(start_value)

    # Send a GET request to the URL
    response = requests.get(url)


    # if the request was successful, to run this code
    if response.status_code == 200:

        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, "html.parser")

        # Initialize empty lists to store job titles and company names
        #job_titles = []
        #company_names = []
        #preferred_qualifications = []
        #job_links = []

        # Find all <li> elements
        job_listings = soup.find_all("li")

        # Extract job titles and company names from each <li>
        for job_listing in job_listings:
            # Extract job title from <h3>
            job_title_element = job_listing.find("h3", class_="base-search-card__title")
            if job_title_element:
                job_title = job_title_element.text.strip()
            else:
                job_title = "N/A"

            # Extract company name from <h4>
            company_name_element = job_listing.find("h4", class_="base-search-card__subtitle")
            if company_name_element:
                company_link = company_name_element.find("a")
                if company_link:
                    company_name = company_link.text.strip()
                else:
                    company_name = "N/A"
            else:
                company_name = "N/A"

            # Extract the link to the individual job posting
            job_link = job_listing.find("a", class_="base-card__full-link")
            if job_link:
                job_url = job_link["href"]
            else:
                job_url = "N/A"

            # Visit the individual job posting's URL if it's not "N/A"
            if job_url != "N/A":
                job_response = requests.get(job_url)
                if job_response.status_code == 200:
                    job_soup = BeautifulSoup(job_response.text, "html.parser")
                    # Extract the preferred qualifications from the JSON data
                    script_element = job_soup.find("script", type="application/ld+json")
                    if script_element:
                        script_content = script_element.text
                        script_data = json.loads(script_content)
                        preferred_qualification = script_data.get("description", "N/A")
                    else:
                        preferred_qualification = "N/A"
                else:
                    preferred_qualification = "N/A"
            else:
                preferred_qualification = "N/A"

            # Append job title, company name, preferred qualifications, and job link to respective lists
            job_titles.append(job_title)
            company_names.append(company_name)
            preferred_qualifications.append(preferred_qualification)
            job_links.append(job_url)

        # Introduce a delay before the next request
        #time.sleep(request_delay)

        # Create a DataFrame from the extracted data
        job_data = pd.DataFrame({
            "Job Title": job_titles,
            "Company Name": company_names,
            "Preferred Qualifications": preferred_qualifications,
            "Link to Job": job_links
        })

        # Print the DataFrame
        print(job_data)

        # You can also save the data to a CSV file if needed
        job_data.to_csv("job_info.csv", index=False)
    else:
        print("Failed to retrieve the page. Status code:", response.status_code)

# Display the DataFrame
display(job_data)
# Out:
#                                             Job Title  \
# 0                                           Scientist
# 1        Growth Data Scientist (Statistical modeling)
# 2                               Junior Data Scientist
# 3                      Data Scientist, Trust & Safety
# 4                Data Scientist (Analysis & Insights)
# 5                           Machine Learning Engineer
# 6              Senior Data Scientist / Data Scientist
# 7   Senior Artificial Intelligence/Machine Learnin...
# 8                           Machine Learning Engineer
# 9                           Machine Learning Engineer
# 10         Senior /Machine Learning Engineer - DSC/EZ
# 11                          Machine Learning Engineer
# 12                   Data Scientist - Fraud Analytics
# 13                            Data Scientist [Search]
# 14                            WeChat - Data Scientist
# 15                              Senior Data Scientist
# 16                              Senior Data Scientist
# 17  Natural Language Processing (NLP) Algorithm En...
# 18  Research Engineer (Machine Learning/ Data Scie...
# 19                   Artificial Intelligence Engineer
# 20                     Data Scientist, Trust & Safety
# 21                               Data Scientist [NLP]
# 22                                     Data Scientist
# 23                   Artificial Intelligence Engineer
# 24                              Senior Data Scientist
#
#                              Company Name  \
# 0               Horizon Quantum Computing
# 1                              Crypto.com
# 2                                     N/A
# 3                                  TikTok
# 4                                     N/A
# 5                                     N/A
# 6   Monetary Authority of Singapore (MAS)
# 7                      Technopals Pte Ltd
# 8                                     N/A
# 9                                     N/A
# 10                         ST Engineering
# 11                                    N/A
# 12                         Robert Walters
# 13                                 Ahrefs
# 14                                Tencent
# 15  Civil Aviation Authority of Singapore
# 16        Energy Research Institute @ NTU
# 17                       Huawei Singapore
# 18       National University of Singapore
# 19                                    N/A
# 20                                 TikTok
# 21                                 Ahrefs
# 22                                    N/A
# 23                         Hendricks Corp
# 24                                   Grab
#
#                              Preferred Qualifications  \
# 0   We are seeking an early-career scientist to he...
# 1   We are seeking a talented and committed Growth...
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# 5                                                 N/A
# 6   &lt;strong&gt;What The Role Is&lt;br&gt;&lt;br...
# 7   &lt;ul&gt;&lt;li&gt;Hands on experience in bui...
# 8                                                 N/A
# 9                                                 N/A
# 10  &lt;p&gt;&lt;strong&gt;Job Description&lt;/str...
# 11                                                N/A
# 12  An exciting Data Scientist - Fraud Analytics j...
# 13  Ahrefs is looking for an experienced Data Scie...
# 14  &lt;strong&gt;Work Mode:&lt;br&gt;&lt;br&gt;&l...
# 15  [What the role is]&lt;p&gt;&lt;br&gt;&lt;/p&gt...
# 16                                                N/A
# 17  &lt;p&gt;Natural Language Processing (NLP) Alg...
# 18                                                N/A
# 19                                                N/A
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23  &lt;strong&gt;About The Job&lt;/strong&gt;&lt;...
# 24  Job Description:&lt;br&gt;&lt;br&gt;&lt;strong...
#
#                                           Link to Job
# 0   https://sg.linkedin.com/jobs/view/scientist-at...
# 1   https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                 N/A
# 3   https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                 N/A
# 5                                                 N/A
# 6   https://sg.linkedin.com/jobs/view/senior-data-...
# 7   https://sg.linkedin.com/jobs/view/senior-artif...
# 8                                                 N/A
# 9                                                 N/A
# 10  https://sg.linkedin.com/jobs/view/senior-machi...
# 11                                                N/A
# 12  https://sg.linkedin.com/jobs/view/data-scienti...
# 13  https://sg.linkedin.com/jobs/view/data-scienti...
# 14  https://sg.linkedin.com/jobs/view/wechat-data-...
# 15  https://sg.linkedin.com/jobs/view/senior-data-...
# 16  https://sg.linkedin.com/jobs/view/senior-data-...
# 17  https://sg.linkedin.com/jobs/view/natural-lang...
# 18  https://sg.linkedin.com/jobs/view/research-eng...
# 19                                                N/A
# 20  https://sg.linkedin.com/jobs/view/data-scienti...
# 21  https://sg.linkedin.com/jobs/view/data-scienti...
# 22                                                N/A
# 23  https://sg.linkedin.com/jobs/view/artificial-i...
# 24  https://sg.linkedin.com/jobs/view/senior-data-...
#                                             Job Title  \
# 0                                           Scientist
# 1        Growth Data Scientist (Statistical modeling)
# 2                               Junior Data Scientist
# 3                      Data Scientist, Trust & Safety
# 4                Data Scientist (Analysis & Insights)
# 5                           Machine Learning Engineer
# 6              Senior Data Scientist / Data Scientist
# 7   Senior Artificial Intelligence/Machine Learnin...
# 8                           Machine Learning Engineer
# 9                           Machine Learning Engineer
# 10         Senior /Machine Learning Engineer - DSC/EZ
# 11                          Machine Learning Engineer
# 12                   Data Scientist - Fraud Analytics
# 13                            Data Scientist [Search]
# 14                            WeChat - Data Scientist
# 15                              Senior Data Scientist
# 16                              Senior Data Scientist
# 17  Natural Language Processing (NLP) Algorithm En...
# 18  Research Engineer (Machine Learning/ Data Scie...
# 19                   Artificial Intelligence Engineer
# 20                     Data Scientist, Trust & Safety
# 21                               Data Scientist [NLP]
# 22                                     Data Scientist
# 23                   Artificial Intelligence Engineer
# 24                              Senior Data Scientist
# 25                                     Data Scientist
# 26  Data Scientist (5.5 Work Week/ Manufacturing/ ...
# 27             Data Scientist - E-commerce operations
# 28                          Machine Learning Engineer
# 29             Machine Learning Engineer (AI,NLP,GPT)
# 30  AIML - Site Reliability Engineer, ML Platform ...
# 31                                  Research Engineer
# 32        Senior Data Scientist - Consumer Incentives
# 33           Machine Learning Engineer, TikTok Search
# 34                           Lead AI Engineer – BCG X
# 35  Machine Learning Engineer (Recommendation) - B...
# 36  AIML - Site Reliability Engineer, ML Platform ...
# 37     Machine Learning Engineer - TikTok - Singapore
# 38      Data Scientist (Compliance) - Global Payments
# 39                                     Data Scientist
# 40                           Software Engineer, AI/ML
# 41  AI/ML ��� Machine Learning Engineer, Siri and ...
# 42              Data Scientist-Global LIVE - Strategy
# 43       Machine Learning Engineer, TikTok E-Commerce
# 44                          Machine Learning Engineer
# 45                          Machine Learning Engineer
# 46                           Data Scientist - Manager
# 47                          Machine Learning Engineer
# 48                            Bioinformatics Engineer
# 49  Senior AI Developer / AI Developer (AI Platfor...
#
#                              Company Name  \
# 0               Horizon Quantum Computing
# 1                              Crypto.com
# 2                                     N/A
# 3                                  TikTok
# 4                                     N/A
# 5                                     N/A
# 6   Monetary Authority of Singapore (MAS)
# 7                      Technopals Pte Ltd
# 8                                     N/A
# 9                                     N/A
# 10                         ST Engineering
# 11                                    N/A
# 12                         Robert Walters
# 13                                 Ahrefs
# 14                                Tencent
# 15  Civil Aviation Authority of Singapore
# 16        Energy Research Institute @ NTU
# 17                       Huawei Singapore
# 18       National University of Singapore
# 19                                    N/A
# 20                                 TikTok
# 21                                 Ahrefs
# 22                                    N/A
# 23                         Hendricks Corp
# 24                                   Grab
# 25                                    N/A
# 26                                    N/A
# 27                                 TikTok
# 28                     Manpower Singapore
# 29                     Manpower Singapore
# 30                                  Apple
# 31                              Big Cloud
# 32                                  Gojek
# 33                                 TikTok
# 34                                  BCG X
# 35                              ByteDance
# 36                                  Apple
# 37                                 TikTok
# 38                              ByteDance
# 39                             TEKsystems
# 40                                    N/A
# 41                                  Apple
# 42                                 TikTok
# 43                                 TikTok
# 44                                    N/A
# 45                                 TikTok
# 46                                     EY
# 47                      Experis Singapore
# 48                             Mason & Co
# 49                                    SAP
#
#                              Preferred Qualifications  \
# 0   We are seeking an early-career scientist to he...
# 1   We are seeking a talented and committed Growth...
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# 5                                                 N/A
# 6   &lt;strong&gt;What The Role Is&lt;br&gt;&lt;br...
# 7   &lt;ul&gt;&lt;li&gt;Hands on experience in bui...
# 8                                                 N/A
# 9                                                 N/A
# 10  &lt;p&gt;&lt;strong&gt;Job Description&lt;/str...
# 11                                                N/A
# 12  An exciting Data Scientist - Fraud Analytics j...
# 13  Ahrefs is looking for an experienced Data Scie...
# 14  &lt;strong&gt;Work Mode:&lt;br&gt;&lt;br&gt;&l...
# 15  [What the role is]&lt;p&gt;&lt;br&gt;&lt;/p&gt...
# 16                                                N/A
# 17  &lt;p&gt;Natural Language Processing (NLP) Alg...
# 18                                                N/A
# 19                                                N/A
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23  &lt;strong&gt;About The Job&lt;/strong&gt;&lt;...
# 24  Job Description:&lt;br&gt;&lt;br&gt;&lt;strong...
# 25                                                N/A
# 26                                                N/A
# 27  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 28                                                N/A
# 29  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 30  &lt;br&gt;&lt;strong&gt;Summary&lt;br&gt;&lt;/...
# 31  &lt;p&gt;&lt;strong&gt;Are you interested in 3...
# 32  &lt;strong&gt;Preamble&lt;/strong&gt;: At Goje...
# 33                                                N/A
# 34  &lt;p&gt;&lt;strong&gt;Who We Are&lt;/strong&g...
# 35                                                N/A
# 36  &lt;br&gt;&lt;strong&gt;Summary&lt;br&gt;&lt;/...
# 37  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 38                                                N/A
# 39  We are looking for a high-caliber data expert ...
# 40                                                N/A
# 41  &lt;br&gt;&lt;strong&gt;Summary&lt;br&gt;&lt;/...
# 42  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 43                                                N/A
# 44                                                N/A
# 45  &lt;p&gt;&lt;strong&gt;Responsibilities&lt;/st...
# 46  At EY, you’ll have the chance to build a caree...
# 47  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 48  &lt;p&gt;&lt;strong&gt;About the Company&lt;/s...
# 49  &lt;strong&gt;We help the world run better&lt;...
#
#                                           Link to Job
# 0   https://sg.linkedin.com/jobs/view/scientist-at...
# 1   https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                 N/A
# 3   https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                 N/A
# 5                                                 N/A
# 6   https://sg.linkedin.com/jobs/view/senior-data-...
# 7   https://sg.linkedin.com/jobs/view/senior-artif...
# 8                                                 N/A
# 9                                                 N/A
# 10  https://sg.linkedin.com/jobs/view/senior-machi...
# 11                                                N/A
# 12  https://sg.linkedin.com/jobs/view/data-scienti...
# 13  https://sg.linkedin.com/jobs/view/data-scienti...
# 14  https://sg.linkedin.com/jobs/view/wechat-data-...
# 15  https://sg.linkedin.com/jobs/view/senior-data-...
# 16  https://sg.linkedin.com/jobs/view/senior-data-...
# 17  https://sg.linkedin.com/jobs/view/natural-lang...
# 18  https://sg.linkedin.com/jobs/view/research-eng...
# 19                                                N/A
# 20  https://sg.linkedin.com/jobs/view/data-scienti...
# 21  https://sg.linkedin.com/jobs/view/data-scienti...
# 22                                                N/A
# 23  https://sg.linkedin.com/jobs/view/artificial-i...
# 24  https://sg.linkedin.com/jobs/view/senior-data-...
# 25                                                N/A
# 26                                                N/A
# 27  https://sg.linkedin.com/jobs/view/data-scienti...
# 28  https://sg.linkedin.com/jobs/view/machine-lear...
# 29  https://sg.linkedin.com/jobs/view/machine-lear...
# 30  https://sg.linkedin.com/jobs/view/aiml-site-re...
# 31  https://sg.linkedin.com/jobs/view/research-eng...
# 32  https://sg.linkedin.com/jobs/view/senior-data-...
# 33  https://sg.linkedin.com/jobs/view/machine-lear...
# 34  https://sg.linkedin.com/jobs/view/lead-ai-engi...
# 35  https://sg.linkedin.com/jobs/view/machine-lear...
# 36  https://sg.linkedin.com/jobs/view/aiml-site-re...
# 37  https://sg.linkedin.com/jobs/view/machine-lear...
# 38  https://sg.linkedin.com/jobs/view/data-scienti...
# 39  https://sg.linkedin.com/jobs/view/data-scienti...
# 40                                                N/A
# 41  https://sg.linkedin.com/jobs/view/ai-ml-%EF%BF...
# 42  https://sg.linkedin.com/jobs/view/data-scienti...
# 43  https://sg.linkedin.com/jobs/view/machine-lear...
# 44                                                N/A
# 45  https://sg.linkedin.com/jobs/view/machine-lear...
# 46  https://sg.linkedin.com/jobs/view/data-scienti...
# 47  https://sg.linkedin.com/jobs/view/machine-lear...
# 48  https://sg.linkedin.com/jobs/view/bioinformati...
# 49  https://sg.linkedin.com/jobs/view/senior-ai-de...
# Failed to retrieve the page. Status code: 429
#                                             Job Title  \
# 0                                           Scientist
# 1        Growth Data Scientist (Statistical modeling)
# 2                               Junior Data Scientist
# 3                      Data Scientist, Trust & Safety
# 4                Data Scientist (Analysis & Insights)
# ..                                                ...
# 70  Machine Learning Engineer, Risk Data Mining, B...
# 71                        Research Scientist - AI Lab
# 72                              Senior Data Scientist
# 73               Machine Learning Engineer (NLP) - CL
# 74                                    Python Engineer
#
#                  Company Name  \
# 0   Horizon Quantum Computing
# 1                  Crypto.com
# 2                         N/A
# 3                      TikTok
# 4                         N/A
# ..                        ...
# 70                     TikTok
# 71               Michael Page
# 72                        N/A
# 73                        N/A
# 74                  Canonical
#
#                              Preferred Qualifications  \
# 0   We are seeking an early-career scientist to he...
# 1   We are seeking a talented and committed Growth...
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# ..                                                ...
# 70                                                N/A
# 71  &lt;ul&gt;&lt;li&gt;OPENNESS: AI, Deep Learnin...
# 72                                                N/A
# 73                                                N/A
# 74  This is a general track role, hiring for every...
#
#                                           Link to Job
# 0   https://sg.linkedin.com/jobs/view/scientist-at...
# 1   https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                 N/A
# 3   https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                 N/A
# ..                                                ...
# 70  https://sg.linkedin.com/jobs/view/machine-lear...
# 71  https://sg.linkedin.com/jobs/view/research-sci...
# 72                                                N/A
# 73                                                N/A
# 74  https://sg.linkedin.com/jobs/view/python-engin...
#
# [75 rows x 4 columns]
#                                             Job Title  \
# 0                                           Scientist
# 1        Growth Data Scientist (Statistical modeling)
# 2                               Junior Data Scientist
# 3                      Data Scientist, Trust & Safety
# 4                Data Scientist (Analysis & Insights)
# ..                                                ...
# 95  Research Scientist (Security Algorithm) - Prod...
# 96  Machine Learning Engineer (Recommendation) - T...
# 97                                     AI/AR Engineer
# 98                              Data Scientist (#821)
# 99  Manager to Senior Manager, Data Scientist, Dat...
#
#                  Company Name  \
# 0   Horizon Quantum Computing
# 1                  Crypto.com
# 2                         N/A
# 3                      TikTok
# 4                         N/A
# ..                        ...
# 95                       Lark
# 96                     TikTok
# 97         Leica Microsystems
# 98                        N/A
# 99    Singapore Tourism Board
#
#                              Preferred Qualifications  \
# 0   We are seeking an early-career scientist to he...
# 1   We are seeking a talented and committed Growth...
# 2                                                 N/A
# 3                                                 N/A
# 4                                                 N/A
# ..                                                ...
# 95  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 96                                                N/A
# 97  &lt;strong&gt;I.general Summary &amp;amp; Over...
# 98                                                N/A
# 99  [What the role is]&lt;br&gt;&lt;br&gt;The Data...
#
#                                           Link to Job
# 0   https://sg.linkedin.com/jobs/view/scientist-at...
# 1   https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                 N/A
# 3   https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                 N/A
# ..                                                ...
# 95  https://sg.linkedin.com/jobs/view/research-sci...
# 96  https://sg.linkedin.com/jobs/view/machine-lear...
# 97  https://sg.linkedin.com/jobs/view/ai-ar-engine...
# 98                                                N/A
# 99  https://sg.linkedin.com/jobs/view/manager-to-s...
#
# [100 rows x 4 columns]
#                                           Job Title  \
# 0                                         Scientist
# 1      Growth Data Scientist (Statistical modeling)
# 2                             Junior Data Scientist
# 3                    Data Scientist, Trust & Safety
# 4              Data Scientist (Analysis & Insights)
# ..                                              ...
# 120     Senior Data Scientist - Data Cycling Center
# 121    Senior Engineer/Engineer (Robotics Software)
# 122                            Application Engineer
# 123  2023 Software Development - Graduate Programme
# 124                               Software Engineer
#
#                   Company Name  \
# 0    Horizon Quantum Computing
# 1                   Crypto.com
# 2                          N/A
# 3                       TikTok
# 4                          N/A
# ..                         ...
# 120                     TikTok
# 121        Temasek Polytechnic
# 122       LKH Precicon Pte Ltd
# 123                  FDM Group
# 124             Esri Singapore
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 120                                                N/A
# 121  &lt;strong&gt;What The Role Is&lt;br&gt;&lt;br...
# 122  &lt;p&gt;&lt;strong&gt;Company Description&lt;...
# 123  &lt;p&gt;Are you incurably curious?&lt;/p&gt;&...
# 124  &lt;p&gt;&lt;strong&gt;Why join us?&lt;/strong...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 120  https://sg.linkedin.com/jobs/view/senior-data-...
# 121  https://sg.linkedin.com/jobs/view/senior-engin...
# 122  https://sg.linkedin.com/jobs/view/application-...
# 123  https://sg.linkedin.com/jobs/view/2023-softwar...
# 124  https://sg.linkedin.com/jobs/view/software-eng...
#
# [125 rows x 4 columns]
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 145            Robotics Automation Engineer (Software)
# 146                                Lead Data Scientist
# 147                              Senior Data Scientist
# 148            Cloud & Automation Development Engineer
# 149  Research Officer / Associate (Full-stack devel...
#
#                       Company Name  \
# 0        Horizon Quantum Computing
# 1                       Crypto.com
# 2                              N/A
# 3                           TikTok
# 4                              N/A
# ..                             ...
# 145                     Toll Group
# 146                      Big Cloud
# 147             WhiteCrow Research
# 148                Morgan McKinley
# 149  Singapore National Eye Centre
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 145  &lt;strong&gt;Company Description&lt;/strong&g...
# 146                                                N/A
# 147                                                N/A
# 148  &lt;p&gt;We are looking for a Cloud Automation...
# 149  &lt;strong&gt;About SERI&lt;br&gt;&lt;br&gt;&l...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 145  https://sg.linkedin.com/jobs/view/robotics-aut...
# 146  https://sg.linkedin.com/jobs/view/lead-data-sc...
# 147  https://sg.linkedin.com/jobs/view/senior-data-...
# 148  https://sg.linkedin.com/jobs/view/cloud-automa...
# 149  https://sg.linkedin.com/jobs/view/research-off...
#
# [150 rows x 4 columns]
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 170            Frontend Developer - Training Provided!
# 171  Scientist in Computer Vision for human action ...
# 172  Senior Assistant Manager (Data Scientist), AIO...
# 173  (Senior) Research Specialist, Translational So...
# 174                                 Solutions Engineer
#
#                                           Company Name  \
# 0                            Horizon Quantum Computing
# 1                                           Crypto.com
# 2                                                  N/A
# 3                                               TikTok
# 4                                                  N/A
# ..                                                 ...
# 170                                  GECO Asia Pte Ltd
# 171  A*STAR - Agency for Science, Technology and Re...
# 172                  National University Health System
# 173          National Council of Social Service (NCSS)
# 174                            Exclusive Networks Asia
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 170  We are looking for motivated IT Professionals ...
# 171  A*STAR Centre for Frontier AI Research (CFAR) ...
# 172  &lt;strong&gt;Overview&lt;/strong&gt;&lt;p&gt;...
# 173  &lt;p&gt;&lt;strong&gt;Job Description Summary...
# 174  &lt;p&gt;&lt;strong&gt;EXCLUSIVE NETWORKS&lt;/...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 170  https://sg.linkedin.com/jobs/view/frontend-dev...
# 171  https://sg.linkedin.com/jobs/view/scientist-in...
# 172  https://sg.linkedin.com/jobs/view/senior-assis...
# 173  https://sg.linkedin.com/jobs/view/senior-resea...
# 174  https://sg.linkedin.com/jobs/view/solutions-en...
#
# [175 rows x 4 columns]
#                                           Job Title  \
# 0                                         Scientist
# 1      Growth Data Scientist (Statistical modeling)
# 2                             Junior Data Scientist
# 3                    Data Scientist, Trust & Safety
# 4              Data Scientist (Analysis & Insights)
# ..                                              ...
# 195                                   KDB Developer
# 196                               Software Engineer
# 197     Senior Software Engineer (Machine Learning)
# 198  Innovation Research Engineer (Permanent, West)
# 199               Software Developer (AI Solutions)
#
#                   Company Name  \
# 0    Horizon Quantum Computing
# 1                   Crypto.com
# 2                          N/A
# 3                       TikTok
# 4                          N/A
# ..                         ...
# 195           First Derivative
# 196       Nordic Group Limited
# 197                        N/A
# 198             Page Personnel
# 199                        N/A
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 195                                                N/A
# 196  Carry out integration and commissioning of an ...
# 197                                                N/A
# 198  &lt;ul&gt;&lt;li&gt;Prestigious German MNC, in...
# 199                                                N/A
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 195  https://sg.linkedin.com/jobs/view/kdb-develope...
# 196  https://sg.linkedin.com/jobs/view/software-eng...
# 197                                                N/A
# 198  https://sg.linkedin.com/jobs/view/innovation-r...
# 199                                                N/A
#
# [200 rows x 4 columns]
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 220                       Backend Development Engineer
# 221  Machine Learning Engineer, Multimedia Arch Dat...
# 222                          Junior Software Developer
# 223                                   Talent Scientist
# 224                             Full Stack - Developer
#
#                    Company Name  \
# 0     Horizon Quantum Computing
# 1                    Crypto.com
# 2                           N/A
# 3                        TikTok
# 4                           N/A
# ..                          ...
# 220                     Tencent
# 221                      TikTok
# 222  Flintex Consulting Pte Ltd
# 223                   Canonical
# 224            Orangekloud Inc.
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 220  &lt;strong&gt;Work Mode:&lt;br&gt;&lt;br&gt;&l...
# 221  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 222  &lt;strong&gt;Job Responsibilities&lt;/strong&...
# 223  The Talent Science team has a mission to ensur...
# 224  &lt;strong&gt;Duties/Responsibilities&lt;br&gt...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 220  https://sg.linkedin.com/jobs/view/backend-deve...
# 221  https://sg.linkedin.com/jobs/view/machine-lear...
# 222  https://sg.linkedin.com/jobs/view/junior-softw...
# 223  https://sg.linkedin.com/jobs/view/talent-scien...
# 224  https://sg.linkedin.com/jobs/view/full-stack-d...
#
# [225 rows x 4 columns]
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 245                    Software Engineer (Instruments)
# 246  Algorithm Engineer (Multi-Modal), TikTok e-Com...
# 247  Assistant Principal Engineer (Artificial Intel...
# 248  Software Engineer in Machine Learning Infra, T...
# 249  Engineer (Smart System Solutions – Smart Machine)
#
#                   Company Name  \
# 0    Horizon Quantum Computing
# 1                   Crypto.com
# 2                          N/A
# 3                       TikTok
# 4                          N/A
# ..                         ...
# 245                   Illumina
# 246                     TikTok
# 247               Michael Page
# 248                     TikTok
# 249              PSA Singapore
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 245  What if the work you did every day could impac...
# 246                                                N/A
# 247                                                N/A
# 248                                                N/A
# 249  &lt;p&gt;Working with a team of engineers to d...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 245  https://sg.linkedin.com/jobs/view/software-eng...
# 246  https://sg.linkedin.com/jobs/view/algorithm-en...
# 247  https://sg.linkedin.com/jobs/view/assistant-pr...
# 248  https://sg.linkedin.com/jobs/view/software-eng...
# 249  https://sg.linkedin.com/jobs/view/engineer-sma...
#
# [250 rows x 4 columns]
#                                          Job Title  \
# 0                                        Scientist
# 1     Growth Data Scientist (Statistical modeling)
# 2                            Junior Data Scientist
# 3                   Data Scientist, Trust & Safety
# 4             Data Scientist (Analysis & Insights)
# ..                                             ...
# 270          Mobile Applications Software Engineer
# 271                    Software Engineer – Backend
# 272  Research Fellow (Data Science), [LKCMedicine]
# 273        Developer Success Engineer (Blockchain)
# 274            Consulting Engineer (Thai Speaking)
#
#                                    Company Name  \
# 0                     Horizon Quantum Computing
# 1                                    Crypto.com
# 2                                           N/A
# 3                                        TikTok
# 4                                           N/A
# ..                                          ...
# 270                                 Doodle Labs
# 271                                      Padlet
# 272  Nanyang Technological University Singapore
# 273                               Austin Werner
# 274                                     MongoDB
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 270  Doodle Labs is the global leader in high-perfo...
# 271  Padlet is building software for a good educati...
# 272  &lt;strong&gt;Research project:&lt;/strong&gt;...
# 273  &lt;p&gt;&lt;strong&gt;Developer Success Engin...
# 274                                                N/A
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 270  https://sg.linkedin.com/jobs/view/mobile-appli...
# 271  https://sg.linkedin.com/jobs/view/software-eng...
# 272  https://sg.linkedin.com/jobs/view/research-fel...
# 273  https://sg.linkedin.com/jobs/view/developer-su...
# 274  https://sg.linkedin.com/jobs/view/consulting-e...
#
# [275 rows x 4 columns]
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 295             Algorithm Engineer - TikTok e-Commerce
# 296        Expression of Interest: Full-Stack Engineer
# 297                    IOT Engineer, Technical Service
# 298                                Full Stack Engineer
# 299  Computer Vision Research Scientist - Intellige...
#
#                                 Company Name  \
# 0                  Horizon Quantum Computing
# 1                                 Crypto.com
# 2                                        N/A
# 3                                     TikTok
# 4                                        N/A
# ..                                       ...
# 295                                   TikTok
# 296            Fingerprint for Success (F4S)
# 297  Jardine Engineering (Singapore) Pte Ltd
# 298                                   Padlet
# 299                                   TikTok
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 295                                                N/A
# 296                                                N/A
# 297                                                N/A
# 298  A technology is only as good as people's abili...
# 299  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 295  https://sg.linkedin.com/jobs/view/algorithm-en...
# 296  https://sg.linkedin.com/jobs/view/expression-o...
# 297  https://sg.linkedin.com/jobs/view/iot-engineer...
# 298  https://sg.linkedin.com/jobs/view/full-stack-e...
# 299  https://sg.linkedin.com/jobs/view/computer-vis...
#
# [300 rows x 4 columns]
#                                         Job Title               Company Name  \
# 0                                       Scientist  Horizon Quantum Computing
# 1    Growth Data Scientist (Statistical modeling)                 Crypto.com
# 2                           Junior Data Scientist                        N/A
# 3                  Data Scientist, Trust & Safety                     TikTok
# 4            Data Scientist (Analysis & Insights)                        N/A
# ..                                            ...                        ...
# 320   Mobile Developer (Android) - Innovation Lab                 Crypto.com
# 321                        Frontend Web Developer           El Pando Pte Ltd
# 322                         Application Developer        IQ Dynamics Pte Ltd
# 323               Engineer - Software Development       SMRT Corporation Ltd
# 324                       Software Engineer (C++)            Space Executive
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 320  We are a team to design, develop, maintain, an...
# 321  🚀 &lt;strong&gt;About El Pando&lt;/strong&gt;:...
# 322  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 323                                                N/A
# 324                                                N/A
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 320  https://sg.linkedin.com/jobs/view/mobile-devel...
# 321  https://sg.linkedin.com/jobs/view/frontend-web...
# 322  https://sg.linkedin.com/jobs/view/application-...
# 323  https://sg.linkedin.com/jobs/view/engineer-sof...
# 324  https://sg.linkedin.com/jobs/view/software-eng...
#
# [325 rows x 4 columns]
#                                           Job Title  \
# 0                                         Scientist
# 1      Growth Data Scientist (Statistical modeling)
# 2                             Junior Data Scientist
# 3                    Data Scientist, Trust & Safety
# 4              Data Scientist (Analysis & Insights)
# ..                                              ...
# 345                             Qliksense Developer
# 346  Senior Scientist, Research & Nutrition Science
# 347         Software Development Engineer (Testing)
# 348            Research Engineer (SIA-NUS Corp Lab)
# 349                            Application Engineer
#
#                          Company Name  \
# 0           Horizon Quantum Computing
# 1                          Crypto.com
# 2                                 N/A
# 3                              TikTok
# 4                                 N/A
# ..                                ...
# 345         Tata Consultancy Services
# 346            Mondelēz International
# 347                 Jobster Singapore
# 348  National University of Singapore
# 349                      Walter Tools
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 345  &lt;p&gt;&lt;strong&gt;Role &amp;amp; Responsi...
# 346                                                N/A
# 347  &lt;strong&gt;Your Responsibilities Will Inclu...
# 348                                                N/A
# 349  Walter is a global industrial group with advan...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 345  https://sg.linkedin.com/jobs/view/qliksense-de...
# 346  https://sg.linkedin.com/jobs/view/senior-scien...
# 347  https://sg.linkedin.com/jobs/view/software-dev...
# 348  https://sg.linkedin.com/jobs/view/research-eng...
# 349  https://sg.linkedin.com/jobs/view/application-...
#
# [350 rows x 4 columns]
#                                         Job Title               Company Name  \
# 0                                       Scientist  Horizon Quantum Computing
# 1    Growth Data Scientist (Statistical modeling)                 Crypto.com
# 2                           Junior Data Scientist                        N/A
# 3                  Data Scientist, Trust & Safety                     TikTok
# 4            Data Scientist (Analysis & Insights)                        N/A
# ..                                            ...                        ...
# 370             Low Level Software Engineer (C++)       Hudson River Trading
# 371             Streaming Media Software Engineer                       BIGO
# 372                        Java Developer (GC/SW)             ST Engineering
# 373                               DevOps Engineer               YOOZOO GAMES
# 374                             Software Engineer                   Teradyne
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 370  We are looking for engineers to power Hudson R...
# 371  &lt;strong&gt;Responsibilities&lt;br&gt;&lt;br...
# 372  &lt;p&gt;The candidate should be able to maint...
# 373  &lt;p&gt;1. Responsible for the coordination a...
# 374  &lt;strong&gt;&lt;strong&gt;Organization &amp;...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 370  https://sg.linkedin.com/jobs/view/low-level-so...
# 371  https://sg.linkedin.com/jobs/view/streaming-me...
# 372  https://sg.linkedin.com/jobs/view/java-develop...
# 373  https://sg.linkedin.com/jobs/view/devops-engin...
# 374  https://sg.linkedin.com/jobs/view/software-eng...
#
# [375 rows x 4 columns]
# Failed to retrieve the page. Status code: 429
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 395  Algorithm Engineer, TikTok eCommerce (Knowledg...
# 396  Backend Engineer (Machine Learning Infrastruct...
# 397                               Application Engineer
# 398        Data Engineering Lead (Fintech | Permanent)
# 399                      Software Development Engineer
#
#                   Company Name  \
# 0    Horizon Quantum Computing
# 1                   Crypto.com
# 2                          N/A
# 3                       TikTok
# 4                          N/A
# ..                         ...
# 395                     TikTok
# 396                     TikTok
# 397                        N/A
# 398         Manpower Singapore
# 399                        N/A
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 395                                                N/A
# 396                                                N/A
# 397                                                N/A
# 398  &lt;p&gt;&lt;br&gt;What you will be doing:&lt;...
# 399                                                N/A
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 395  https://sg.linkedin.com/jobs/view/algorithm-en...
# 396  https://sg.linkedin.com/jobs/view/backend-engi...
# 397                                                N/A
# 398  https://sg.linkedin.com/jobs/view/data-enginee...
# 399                                                N/A
#
# [400 rows x 4 columns]
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 420      Product Development Software Engineer (C/C++)
# 421  Research Fellow/Engineer (Chemical Plume Tomog...
# 422                            Unreal Engine Developer
# 423  Software Engineer - Low-code Platform - Singapore
# 424  Backend Software Engineer - TikTok Live Money ...
#
#                           Company Name  \
# 0            Horizon Quantum Computing
# 1                           Crypto.com
# 2                                  N/A
# 3                               TikTok
# 4                                  N/A
# ..                                 ...
# 420                     ST Engineering
# 421  Singapore Institute of Technology
# 422                         Bifrost AI
# 423                          ByteDance
# 424                             TikTok
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 420  &lt;p&gt;&lt;strong&gt;ST Engineering&lt;/stro...
# 421  &lt;strong&gt;Key Responsibilities&lt;br&gt;&l...
# 422  At Bifrost, we are building generative engines...
# 423                                                N/A
# 424  &lt;p&gt;TikTok is the leading destination for...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 420  https://sg.linkedin.com/jobs/view/product-deve...
# 421  https://sg.linkedin.com/jobs/view/research-fel...
# 422  https://sg.linkedin.com/jobs/view/unreal-engin...
# 423  https://sg.linkedin.com/jobs/view/software-eng...
# 424  https://sg.linkedin.com/jobs/view/backend-soft...
#
# [425 rows x 4 columns]
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 420      Product Development Software Engineer (C/C++)
# 421  Research Fellow/Engineer (Chemical Plume Tomog...
# 422                            Unreal Engine Developer
# 423  Software Engineer - Low-code Platform - Singapore
# 424  Backend Software Engineer - TikTok Live Money ...
#
#                           Company Name  \
# 0            Horizon Quantum Computing
# 1                           Crypto.com
# 2                                  N/A
# 3                               TikTok
# 4                                  N/A
# ..                                 ...
# 420                     ST Engineering
# 421  Singapore Institute of Technology
# 422                         Bifrost AI
# 423                          ByteDance
# 424                             TikTok
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 420  &lt;p&gt;&lt;strong&gt;ST Engineering&lt;/stro...
# 421  &lt;strong&gt;Key Responsibilities&lt;br&gt;&l...
# 422  At Bifrost, we are building generative engines...
# 423                                                N/A
# 424  &lt;p&gt;TikTok is the leading destination for...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 420  https://sg.linkedin.com/jobs/view/product-deve...
# 421  https://sg.linkedin.com/jobs/view/research-fel...
# 422  https://sg.linkedin.com/jobs/view/unreal-engin...
# 423  https://sg.linkedin.com/jobs/view/software-eng...
# 424  https://sg.linkedin.com/jobs/view/backend-soft...
#
# [425 rows x 4 columns]

# %%
# Function to clean and extract preferred qualifications in point form
def clean_and_extract_preferred_qualifications(text):

    # Remove unwanted HTML tags
    cleaned_text = re.sub(r'&lt;/?(strong|ul|li|br)&gt;', '', text)

    # Remove unwanted HTML tags and entities
    #cleaned_text = re.sub(r'<[^>]*>', '', text)  # Remove HTML tags
    #cleaned_text = re.sub(r'&[A-Za-z]+;', ' ', cleaned_text)  # Remove HTML entities

    # Extract information after headers (e.g., "Requirements" or "Preferred Qualifications")
    headers = ["Requirements", "Preferred Qualifications", "Requirments", "What We Are Looking For", "Basic Requirements", "The Must-Haves"]

    info_dict = {}

    for header in headers:
        pattern = re.compile(f"{header}(.*?)(?={ '|'.join(headers) }|$)", re.DOTALL| re.IGNORECASE)
        match = pattern.search(cleaned_text)
        if match:
            info = match.group(1).strip()
            info_dict[header] = info
            return info

        else:
            return "N/A"

# Cleaning portion can be further improved*
# For this project, scrapping more JD to pick out non-N/A cases

# %%
# Apply the function to clean the "Preferred Qualifications" column
job_data['Preferred Qualifications Cleaned'] = job_data['Preferred Qualifications'].apply(clean_and_extract_preferred_qualifications)

# Convert the list of qualifications to a formatted string
job_data['Preferred Qualifications Cleaned'] = job_data['Preferred Qualifications Cleaned'].apply(lambda x: ''.join(x))

# Display the DataFrame
display(job_data)

job_data.to_csv("LinkedIn_JD_Scrapped_500rows.csv", index=False)
# Out:
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 2                                Junior Data Scientist
# 3                       Data Scientist, Trust & Safety
# 4                 Data Scientist (Analysis & Insights)
# ..                                                 ...
# 420      Product Development Software Engineer (C/C++)
# 421  Research Fellow/Engineer (Chemical Plume Tomog...
# 422                            Unreal Engine Developer
# 423  Software Engineer - Low-code Platform - Singapore
# 424  Backend Software Engineer - TikTok Live Money ...
#
#                           Company Name  \
# 0            Horizon Quantum Computing
# 1                           Crypto.com
# 2                                  N/A
# 3                               TikTok
# 4                                  N/A
# ..                                 ...
# 420                     ST Engineering
# 421  Singapore Institute of Technology
# 422                         Bifrost AI
# 423                          ByteDance
# 424                             TikTok
#
#                               Preferred Qualifications  \
# 0    We are seeking an early-career scientist to he...
# 1    We are seeking a talented and committed Growth...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 420  &lt;p&gt;&lt;strong&gt;ST Engineering&lt;/stro...
# 421  &lt;strong&gt;Key Responsibilities&lt;br&gt;&l...
# 422  At Bifrost, we are building generative engines...
# 423                                                N/A
# 424  &lt;p&gt;TikTok is the leading destination for...
#
#                                            Link to Job  \
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 2                                                  N/A
# 3    https://sg.linkedin.com/jobs/view/data-scienti...
# 4                                                  N/A
# ..                                                 ...
# 420  https://sg.linkedin.com/jobs/view/product-deve...
# 421  https://sg.linkedin.com/jobs/view/research-fel...
# 422  https://sg.linkedin.com/jobs/view/unreal-engin...
# 423  https://sg.linkedin.com/jobs/view/software-eng...
# 424  https://sg.linkedin.com/jobs/view/backend-soft...
#
#                       Preferred Qualifications Cleaned
# 0    A MSc degree in Computer Science, Physics, a r...
# 1    , you can learn more from our talent acquisiti...
# 2                                                  N/A
# 3                                                  N/A
# 4                                                  N/A
# ..                                                 ...
# 420  into effective and efficient solutions. Work a...
# 421  Have relevant competence in the areas of data ...
# 422  Experience with Unreal Engine (Any version, bu...
# 423                                                N/A
# 424                                                N/A
#
# [425 rows x 5 columns]

# %%
# Drop all rows with N/A 
# Take only Job Title, Company, Preferred Qualifications Cleaned, Link to Job 

# Drop rows with "N/A" in the "Preferred Qualifications Cleaned" column
# Select specific columns
job_data_dropNA = job_data[job_data['Preferred Qualifications Cleaned'] != "N/A"]
job_data_dropNA = job_data_dropNA.loc[:, ["Job Title", "Company Name", "Preferred Qualifications Cleaned", "Link to Job"]]

# Rename the "Preferred Qualifications Cleaned" column to "Preferred Qualifications"
job_data_dropNA = job_data_dropNA.rename(columns={"Preferred Qualifications Cleaned": "Preferred Qualifications"})

# Display the DataFrame
display(job_data_dropNA)

# Select specific columns

job_data_dropNA.to_csv("LinkedIn_JD_Scrapped_500rows_Cleaned.csv", index=False)
# Out:
#                                              Job Title  \
# 0                                            Scientist
# 1         Growth Data Scientist (Statistical modeling)
# 10          Senior /Machine Learning Engineer - DSC/EZ
# 12                    Data Scientist - Fraud Analytics
# 13                             Data Scientist [Search]
# ..                                                 ...
# 416                     Application Programmer - Murex
# 418        Software Engineer (Enterprise Applications)
# 420      Product Development Software Engineer (C/C++)
# 421  Research Fellow/Engineer (Chemical Plume Tomog...
# 422                            Unreal Engine Developer
#
#                           Company Name  \
# 0            Horizon Quantum Computing
# 1                           Crypto.com
# 10                      ST Engineering
# 12                      Robert Walters
# 13                              Ahrefs
# ..                                 ...
# 416                       MIGSO-PCUBED
# 418          DSO National Laboratories
# 420                     ST Engineering
# 421  Singapore Institute of Technology
# 422                         Bifrost AI
#
#                               Preferred Qualifications  \
# 0    A MSc degree in Computer Science, Physics, a r...
# 1    , you can learn more from our talent acquisiti...
# 10   , design, develop, test and maintain Machine L...
# 12   , understand business processes and conduct da...
# 13   together with Product Development, Design and ...
# ..                                                 ...
# 416  &lt;/u&gt;&lt;/p&gt;&lt;p&gt;At least a Bachel...
# 418               , and ensure the fulfilment of these
# 420  into effective and efficient solutions. Work a...
# 421  Have relevant competence in the areas of data ...
# 422  Experience with Unreal Engine (Any version, bu...
#
#                                            Link to Job
# 0    https://sg.linkedin.com/jobs/view/scientist-at...
# 1    https://sg.linkedin.com/jobs/view/growth-data-...
# 10   https://sg.linkedin.com/jobs/view/senior-machi...
# 12   https://sg.linkedin.com/jobs/view/data-scienti...
# 13   https://sg.linkedin.com/jobs/view/data-scienti...
# ..                                                 ...
# 416  https://sg.linkedin.com/jobs/view/application-...
# 418  https://sg.linkedin.com/jobs/view/software-eng...
# 420  https://sg.linkedin.com/jobs/view/product-deve...
# 421  https://sg.linkedin.com/jobs/view/research-fel...
# 422  https://sg.linkedin.com/jobs/view/unreal-engin...
#
# [172 rows x 4 columns]
